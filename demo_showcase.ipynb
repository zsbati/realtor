# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Realtor: Feature Showcase\n",
    "\n",
    "Welcome to the showcase for the **Real Estate Visit Management System (Realtor)**! This notebook provides an overview of the main features and workflows of the web application, with annotated screenshots and explanations. \n",
    "\n",
    "> ⭐ **Tip:** For a live demo, check out the repo README for setup instructions, or [run this app locally](https://github.com/zsbati/realtor#setup)."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Dashboard Overview\n",
    "\n",
    "- See today's and upcoming visits at a glance\n",
    "- Quick access to creating new visits\n",
    "- User management, exports, and statistics\n",
    "\n",
    "![Dashboard Screenshot](dashboard_screenshot.png)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Managing Visits\n",
    "\n",
    "- Create, edit, and delete visits\n",
    "- Schedule different visit types (in-person, phone, email)\n",
    "- Track status: scheduled, completed, cancelled, forgotten\n",
    "\n",
    "![Visit Management Screenshot](visit_management.png)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Contract Management\n",
    "\n",
    "- Create and manage property contracts\n",
    "- Track contract status and generate PDFs\n",
    "- E-signature support\n",
    "\n",
    "![Contract Management Screenshot](contract_management.png)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Reports and Exports\n",
    "\n",
    "- Filter and export visits and contracts\n",
    "- Excel and PDF export options\n",
    "- View statistics about completed visits\n",
    "\n",
    "![Reports Screenshot](reports.png)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. User Management\n",
    "\n",
    "- Add and manage staff users\n",
    "- Assign roles and reset passwords\n",
    "\n",
    "![User Management Screenshot](user_management.png)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "---\n",
    "\n",
    "## Try it Yourself\n",
    "\n",
    "To experience these features, clone the repository and follow the [setup steps](https://github.com/zsbati/realtor#setup) in the README.\n",
    "\n",
    "> _Want a live Binder demo? Let me know, and I’ll help set one up!_"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
